# %% [markdown]
# <a href="https://colab.research.google.com/github/MuriloKrominski/EmpresasBrasileiras2020/blob/master/EmpresasBrasileiras2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Por Murilo Krominski.

# %% [markdown]
# # Empresas Brasileiras e Sócios<br>
# Dados capturados em 19 de Julho de 2020.<br>
# 203.297.292 de registros.<br>
# Quadros societários e de administradores das pessoas jurídicas brasileiras.<br>
# Fonte original: Receita Federal do Brasil<br>
# Licença: Creative Commons Attribution-ShareAlike 4.0 International (CC BY-SA 4.0)<br>

# %% [markdown]
# ## empresa.csv - 44.467.068 de registros.
# cnpj<br>
# identificador_matriz_filial<br>
# razao_social<br>
# nome_fantasia<br>
# situacao_cadastral<br>
# data_situacao_cadastral<br>
# motivo_situacao_cadastral<br>
# nome_cidade_exterior<br>
# codigo_natureza_juridica<br>
# data_inicio_atividade<br>
# cnae_fiscal<br>
# descricao_tipo_logradouro<br>
# logradouro<br>
# numero<br>
# complemento<br>
# bairro<br>
# cep<br>
# uf<br>
# codigo_municipio<br>
# municipio<br>
# ddd_telefone_1<br>
# ddd_telefone_2<br>
# ddd_fax<br>
# qualificacao_do_responsavel<br>
# capital_social<br>
# porte,opcao_pelo_simples<br>
# data_opcao_pelo_simples<br>
# data_exclusao_do_simples<br>
# opcao_pelo_mei<br>
# situacao_especial<br>
# data_situacao_especial<br>
# https://drive.google.com/drive/folders/1NhpfbNxLZ3SFxmgHQfgW0QKObePsdf85?usp=sharing<br>
# SHA512SUMS:3da3737b63e556000baf981017ece05e66dab1f755baf000e20c1797e189463966afa2f12a4977ab6e3a993f1a0e3e4619a182c61ab038868f6903dcfe9f5a12

# %% [markdown]
# ## socios.csv - 27.176.265 de registros.
# cnpj<br>
# identificador_de_socio<br>
# nome_socio<br>
# cnpj_cpf_do_socio<br>
# codigo_qualificacao_socio<br>
# percentual_capital_social<br>
# data_entrada_sociedade<br>
# cpf_representante_legal<br>
# nome_representante_legal<br>
# codigo_qualificacao_representante_legal<br>
# https://drive.google.com/drive/folders/1NhpfbNxLZ3SFxmgHQfgW0QKObePsdf85?usp=sharing<br>
# SHA512SUMS:6df2eb0281857dbc9cdc09bba58c32d92b08387ee73b9b869d05d26ec38cabc34d9cf9a6d3d681c491cff38513a13147d0c7207b63f583573aa32424bbe5f129

# %% [markdown]
# ## cnae_cnpj.csv - 101.394.871 de registros.
# cnpj<br>
# cnae<br>
# primaria<br>
# https://drive.google.com/drive/folders/1NhpfbNxLZ3SFxmgHQfgW0QKObePsdf85?usp=sharing<br>
# SHA512SUMS:5b5c105fe008ae26683439b34c8502a6da741cfcf4159fd7d33f3c50d35ae7fc3b822d1012db22b4f752538ee7ffe42902f62bb49f532f41e799a293978702d1

# %% [markdown]
# ## cnae_secundaria.csv - 56.927.802 de registros.
# cnpj<br>
# cnae<br>
# https://drive.google.com/drive/folders/1NhpfbNxLZ3SFxmgHQfgW0QKObePsdf85?usp=sharing<br>
# SHA512SUMS:fc95a09ebc160d0a503f31c4279ea723b67b54c8dcaeda7143b1df34ff65c5f2b68754d590ad966e78a4b4abdbdff599a64114ed8303be3bc7646876e3a83ab6

# %% [markdown]
# ## holding.csv - 507.551 de registros.
# holding_cnpj<br>
# holding_razao_social<br>
# cnpj<br>
# razao_social<br>
# codigo_qualificacao_socia<br>
# qualificacao_socia<br>
# https://drive.google.com/drive/folders/1NhpfbNxLZ3SFxmgHQfgW0QKObePsdf85?usp=sharing<br>
# SHA512SUMS:5902e40b818284b46b41dca2beea8613a4ad8b45b0e2e4462f565d9623208703ba052b7fd99ba7311ee7526cf76d23a858fe9fdb06492c425afb54e17ae0307c

# %% [markdown]
# # Carregamento dos dados CSV

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# drive.mount("/content/drive", force_remount=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# from google.colab.data_table import DataTable

# %%
# empresa = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Empresa/empresa.csv")

# %%
# socio = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Empresa/socio.csv")

# %%
# holding = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Empresa/holding.csv")

# %%
# cnae_cnpj = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Empresa/cnae_cnpj.csv")

# %%
# cnae_secundaria = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Empresa/cnae_secundaria.csv")

# %% [markdown]
# ## Visualização bruta dos dados

# %% [markdown]
# ### empresa

# %%
# empresa

# %%
# DataTable(empresa)

# %% [markdown]
# ### socio

# %%
# socio

# %%
# DataTable(socio)

# %% [markdown]
# ### holding

# %%
# holding

# %%
# DataTable(holding)

# %% [markdown]
# ### cnae_cnpj

# %%
# cnae_cnpj

# %%
# DataTable(cnae_cnpj)

# %% [markdown]
# ### cnae_secundaria

# %%
# cnae_secundaria

# %%
# DataTable(cnae_secundaria)

# %% [markdown]
# # TESTES

# %%
# import pandas as pd

# from google.colab import drive
# drive.mount("/content/drive")

# socio = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Empresa/socio.csv", low_memory=True)

# from google.colab.data_table import DataTable
# DataTable(socio, max_rows=27176264)
